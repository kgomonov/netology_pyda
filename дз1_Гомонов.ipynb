# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
len(long_phrase)>len(short_phrase)

#насколько я понял, в данном случае писать if else нецелесообразно в том смысле,
#что одно действие итак выдаст проверку на условие
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
bite_size = int(input("Введите значение объема файла в байтах: "))
mb_size = bite_size / 1024 / 1024  
print ("Объем файла равен ", round(mb_size,2), "Mb")
# Out:
# Введите значение объема файла в байтах: 20000000000
# Объем файла равен  19073.49 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
month = input ("Введите месяц: ")
day = int(input("Введите число: "))

if day > 20 and month == "январь" or day <=19 and month == "февраль":
    print ("Водолей")
elif day > 20 and month == "февраль" or day <=20 and month == "март":
    print ("Рыбы")
elif day > 21 and month == "март" or day <= 19 and month == "апрель":
    print ("Овен")
elif day > 20 and month == "апрель" or day <= 20 and month == "май":
    print ("Телец")
elif day > 21 and month == "май" or day <= 20 and month == "июнь":
    print ("Близнецы")
elif day > 21 and month == "июнь" or day <= 22 and month == "июль":
    print ("Рак")
elif day > 23 and month == "август" or day <= 22 and month == "сентябрь":
    print ("Дева")
elif day > 23 and month == "сентябрь" or day <= 23 and month == "октября":
    print ("Весы")
elif day > 24 and month == "октябрь" or day <= 23 and month == "ноябрь":
    print ("Скорпион")
elif day > 24 and month == "ноябрь" or day <= 21 and month == "декабрь":
    print ("Стрелец")
else:
    print ("Козерог")
# Out:
# Введите месяц: декабрь
# Введите число: 25
# Козерог

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
zp = int(input("Введите заработанную плату в месяц: "))
zp_ip = int(input("Введите сколько процентов уходит на ипотеку: "))
zp_life = int(input("Введите сколько процентов уходит на жизнь: "))
premiya = int(input("Введите количество премий за год: "))

ipoteka_v_mes = zp * zp_ip / 100
ipoteka_v_god = ipoteka_v_mes * 12
life = zp * zp_life / 100
pensiya_v_mes = zp - ipoteka_v_mes - life
pensiya_v_god = pensiya_v_mes * 12 + zp / 2 * premiya

print ("Вывод: На ипотеку было потрачено ", ipoteka_v_god, " рублей. Было Накоплено: ",pensiya_v_god, "рублей" )
# Out:
# Введите заработанную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий за год: 2
# Вывод: На ипотеку было потрачено  360000.0  рублей. Было Накоплено:  340000.0 рублей
